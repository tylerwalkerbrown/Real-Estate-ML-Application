# %% [markdown]
# # Zillow ML Application
# Project Function: This application will be used for analyzing hot real estate deals based on geo location.
# # Visuals
# - Mapbox
# - Histogram
# ## What will we be analyzing ?
# - Fair Market Price by neighborhood cluster
# - Top deals

# %%
import requests
import pandas as pd

# %%
#Search String
pd.set_option('display.max_columns', None)
city = 'Boston'
state = 'MA'
search_str = city + ', ' +state
print('Search string:', search_str)
# Out:
# Search string: Boston, MA

# %%
#API for For Sale
url = ""
querystring = {"location":search_str}

headers = {
    'x-rapidapi-host': "",
    'x-rapidapi-key': ""
    }

# %%
response = requests.request("GET", url, headers=headers, params=querystring)
json = response.json()
df = pd.json_normalize(data=json['props'])

# %% [markdown]
# ## Home Types Availble Through API
#
# RecentlySold are available:
#
# - Homes_for_You
# - Price_High_Low
# - Price_Low_High
# - Newest
# - Bedrooms
# - Bathrooms
# - Square_Feet
# - Lot_Size
#
# default Homes_for_You
#
# For status_type = ForRent are available:
#
# - Verified_Source
# - Payment_High_Low
# - Payment_Low_High
# - Newest
# - Bedrooms
# - Bathrooms
# - Square_Feet
# - Lot_Size
#
# default Verified_Source

# %%
df.head()
# Out:
#   dateSold   propertyType  lotAreaValue  \
# 0     None  SINGLE_FAMILY        9000.0
# 1     None          CONDO           NaN
# 2     None  SINGLE_FAMILY        1980.0
# 3     None  SINGLE_FAMILY        1785.0
# 4     None  SINGLE_FAMILY        4800.0
#
#                                      address  priceChange  zestimate  \
# 0          95 Loring St, Hyde Park, MA 02136          NaN   525512.0
# 1  1 Franklin St UNIT 4204, Boston, MA 02110          NaN  3681318.0
# 2         8 Claremont Park, Boston, MA 02118          NaN        NaN
# 3           504 E Broadway, Boston, MA 02127          NaN        NaN
# 4         5 Lewiston St, Hyde Park, MA 02136          NaN   553797.0
#
#                                               imgSrc    price  bedrooms  \
# 0  https://photos.zillowstatic.com/fp/49eac7ae6c3...   499900         3
# 1  https://photos.zillowstatic.com/fp/f6eab9d54be...  3900000         3
# 2  https://photos.zillowstatic.com/fp/3cfd53392ba...  5495000         5
# 3  https://photos.zillowstatic.com/fp/c9eaea44d06...  1599900         4
# 4  https://photos.zillowstatic.com/fp/696de1d5607...   525000         3
#
#   contingentListingType  longitude   latitude listingStatus        zpid  \
# 0                  None -71.124150  42.245888      FOR_SALE    59128352
# 1                  None -71.059555  42.356316      FOR_SALE   246887237
# 2                  None -71.081230  42.341850      FOR_SALE   113389934
# 3                  None        NaN        NaN      FOR_SALE  2066646258
# 4                  None -71.112656  42.266773      FOR_SALE    59125651
#
#    rentZestimate daysOnZillow  bathrooms  livingArea country currency  \
# 0         3200.0           -1          2        1433     USA      USD
# 1        14357.0           -1          3        2096     USA      USD
# 2         5441.0           -1          7        4440     USA      USD
# 3            NaN           -1          3        2868     USA      USD
# 4         3499.0           -1          2        1270     USA      USD
#
#   lotAreaUnit  hasImage           variableData.text variableData.type  \
# 0        sqft      True           Open: Sat. 12-2pm        OPEN_HOUSE
# 1        None      True  Open: Sat. 11:30am-12:30pm        OPEN_HOUSE
# 2        sqft      True        Open: Sun. 12-1:30pm        OPEN_HOUSE
# 3        sqft      True         Open: Thu. 4:30-6pm        OPEN_HOUSE
# 4        sqft      True     Open: Sat. 11am-12:30pm        OPEN_HOUSE
#
#    listingSubType.is_FSBA listingSubType.is_openHouse       unit  variableData
# 0                    True                        True        NaN           NaN
# 1                    True                        True  Unit 4204           NaN
# 2                    True                        True        NaN           NaN
# 3                    True                        True        NaN           NaN
# 4                    True                        True        NaN           NaN

# %%
df.columns
# Out:
# Index(['dateSold', 'propertyType', 'lotAreaValue', 'address', 'priceChange',
#        'zestimate', 'imgSrc', 'price', 'bedrooms', 'contingentListingType',
#        'longitude', 'latitude', 'listingStatus', 'zpid', 'rentZestimate',
#        'daysOnZillow', 'bathrooms', 'livingArea', 'country', 'currency',
#        'lotAreaUnit', 'hasImage', 'variableData.text', 'variableData.type',
#        'listingSubType.is_FSBA', 'listingSubType.is_openHouse', 'unit',
#        'variableData'],
#       dtype='object')

# %% [markdown]
# # Variable Uses
#
# ### KNN:
# - Zpid ? possible unique geospatial identifier
# - Lat/Long
# - Property Type
#
# ### K means
# Iterations have to be done over different property types
# - Lat/Long (latitude / longitude)
#
# ### Regression
# Has to be filtered on home type
# - Price (price)
# - SQFT

# %% [markdown]
# # Junk Code

# %% [markdown]
# import plotly.express as px
# import numpy as np
# df.fillna(df.mean(), inplace=True)
#
#
# X = df[['propertyType', 'latitude', 'longitude']]
# X = pd.get_dummies(X, columns=['propertyType'])
# kmeans = KMeans(n_clusters=3)
# kmeans.fit(X)
# labels = kmeans.predict(X)
#
# fig = px.scatter_mapbox(df, lat='latitude', lon='longitude', color='propertyType', zoom=10,
#                         mapbox_style='open-street-map', width=800, height=600)
#
# # Generate dot sizes based on home price
# dot_sizes = np.interp(df['price'], (df['price'].min(), df['price'].max()), (5, 15))
#
# # Add scatter trace with dot sizes and home price labels
# fig.add_trace(px.scatter_mapbox(df, lat='latitude', lon='longitude', size=dot_sizes, color='propertyType',
#                                  hover_data=['price']).data[0])
#
# # Add home price labels
# for i, row in df.iterrows():
#     fig.add_annotation(
#         dict(
#             text=row['price'],
#             x=row['longitude'],
#             y=row['latitude'],
#             font=dict(color='black', size=10),
#             showarrow=False,
#         )
#     )
#
# # Update the layout to adjust the font size of the title and legend
# fig.update_layout(title='Property Clusters', title_font_size=20, legend_font_size=16)
